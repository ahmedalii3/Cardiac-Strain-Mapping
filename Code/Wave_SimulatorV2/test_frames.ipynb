# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
frame1 = np.load('/Users/osama/GP-2025-Strain/Code/Wave_SimulatorV2/generatedData/Frames/patient005_frame13_slice_2_ACDC_#15_1.npy')
frame2 = np.load('/Users/osama/GP-2025-Strain/Code/Wave_SimulatorV2/generatedData/Frames/patient005_frame13_slice_2_ACDC_#15_2.npy')
disp_x = np.load('/Users/osama/GP-2025-Strain/Code/Wave_SimulatorV2/generatedData/Displacements/patient005_frame13_slice_2_ACDC_#15_x.npy')
disp_y = np.load('/Users/osama/GP-2025-Strain/Code/Wave_SimulatorV2/generatedData/Displacements/patient005_frame13_slice_2_ACDC_#15_y.npy')

# %%
plt.imshow(frame2-frame1)

# %%
from helper import load_image
orig = load_image("/Users/osama/GP-2025-Strain/Data/ACDC/train_numpy/patient027/patient027_frame11_slice_4_ACDC.npy")
plt.imshow(orig)

# %%
def apply_displacement(image, x_displacement, y_displacement):
        # Prepare meshgrid for remap
        height, width, _ = image.shape
        x, y = np.meshgrid(np.arange(width), np.arange(height))

        # Apply displacement (scale the displacements for more visible effect)
        x_new = (x + x_displacement).astype(np.float32)
        y_new = (y + y_displacement).astype(np.float32)

        # Warp the image using remap for both x and y displacements
        displaced_image = cv2.remap(image, x_new, y_new, interpolation=cv2.INTER_LANCZOS4, borderMode=cv2.BORDER_REFLECT)
        return displaced_image



displaced_image = apply_displacement(frame1, disp_x, disp_y)

# %%
plt.imshow(displaced_image-frame2)

# %%
plt.imshow(frame1)

# %%
plt.imshow(frame2)

# %%
plt.imshow(displaced_image)

# %%
plt.imshow(frame2-frame1)
